# %% [markdown]
# #  PROBLEM STATEMENT

# %% [markdown]
# ## 1.Business Understanding

# %% [markdown]
# The used car dataset is obtained from [Truecar](https://www.truecar.com/used-cars-for-sale/) which is a leading automotive digital marketplace that seeks to make car buying and selling easy, transparent and efficient.
#
# From discovery to delivery, consumers can use TrueCar to explore new and used vehicles from an expansive, cross-brand selection of inventory from our vast network of Certified Dealers.
#
# Founded in 2005, TrueCar has built a trusted brand and a strong reputation for providing consumers with useful tools, research, market context and pricing transparency as they embark on their car-buying journey. The Company is bringing more of the purchasing process online by allowing consumers to find a new or used vehicle that is right for them, secure financing, sell or trade-in their current vehicle and complete their purchase with a reputable dealer all from the comfort of their home.

# %% [markdown]
# ### Objective

# %% [markdown]
# To create a model that predicts prices of used cars in New York and Carlifonia

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd # for data manipulation,data processing, CSV file I/O (e.g. pd.read_csv)
import pandas.io.sql as sqlio # allows manipulation of a Pandas Dataframe using SQL
import psycopg2 as ps # used to perform operations on PostgreSQL using python
import numpy as np # for numerical calculation
import matplotlib.pyplot as plt # for plotting
import seaborn as sns # for interactive plotting with colors /used for plot interactive graph. I like it most for plot
from sklearn.preprocessing import LabelEncoder # Encode target labels with value between 0 and n_classes-1
from scipy import stats # offers variety of statistic functions
from sklearn.preprocessing import StandardScaler # removes the mean and scales each feature/variable to unit variance.
from sklearn.model_selection import train_test_split # to split arrays or matrices into random train and test subsets
from sklearn.linear_model import LinearRegression # For building machine learning model
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dense,Activation
from sklearn import metrics # for evaluating our model
import pickle # Pickle is used for serializing and de-serializing a Python object structure
# %matplotlib inline

# %% [markdown]
# ### Load Dataset

# %%
#Establishing a connection between jupyter otebook and postgresql database 

conn2 = ps.connect(dbname='postgres',
                   user='postgres',
                   password='0112358',
                   host='localhost',
                   port='5432' )

# %%
#loading our dataset

sql = """select * from used_car_data"""
df = sqlio.read_sql_query(sql,conn2)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4880\1332430663.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = sqlio.read_sql_query(sql,conn2)

# %% [markdown]
# ## 2.Data Understanding

# %%
#previewing the first 5 rows of the data
df.head()
# Out:
#    index          brand           model  mileage  year fuel_type  ownerCount  \
# 0      0  Mercedes-Benz             GLC    18386  2019       Gas         1.0
# 1      1  Mercedes-Benz         C-Class    41829  2018       Gas         1.0
# 2      2  Mercedes-Benz         C-Class    22667  2018       Gas         1.0
# 3      3        Ferrari  612 Scaglietti    15104  2005       Gas         2.0
# 4      4  Mercedes-Benz             GLA    33163  2019       Gas         1.0
#
#    accidentCount transmission      city state body_style  \
# 0              0    Automatic  New York    NY        SUV
# 1              0    Automatic  New York    NY      Sedan
# 2              0    Automatic  New York    NY      Sedan
# 3              0    Automatic  New York    NY      Coupe
# 4              0    Automatic  New York    NY        SUV
#
#                            engine drive_train   price
# 0  2.0L Inline-4 Gas Turbocharged         AWD   37906
# 1  2.0L Inline-4 Gas Turbocharged         AWD   31901
# 2  2.0L Inline-4 Gas Turbocharged         AWD   33906
# 3                   5.8L V-12 Gas         RWD  110500
# 4  2.0L Inline-4 Gas Turbocharged         AWD   32904

# %%
#previewing 10 rows
df.sample(10)
# Out:
#       index      brand           model  mileage  year fuel_type  ownerCount  \
# 4882   4884     Toyota      Highlander    25455  2019       Gas         1.0
# 7190   7199      Honda         Odyssey    13125  2019       Gas         1.0
# 8980   8990      Mazda            CX-5    29779  2019       Gas         1.0
# 3656   3657       Jeep        Cherokee    27180  2019       Gas         2.0
# 4308   4309        BMW              X3   105755  2011       Gas         3.0
# 2976   2977      Honda          Accord    15571  2018       Gas         3.0
# 139     139  Chevrolet  Silverado 1500   182555  2006       Gas         1.0
# 5516   5518      Dodge         Charger    39333  2018       Gas         1.0
# 1010   1010      Volvo            XC90    53832  2019       Gas         1.0
# 3299   3300       Jeep  Grand Cherokee    32195  2018       Gas         1.0
#
#       accidentCount transmission       city state    body_style  \
# 4882              1    Automatic   Brooklyn    NY           SUV
# 7190              0    Automatic  Daly City    CA       Minivan
# 8980              2    Automatic  Daly City    CA           SUV
# 3656              0    Automatic   Bensalem    PA           SUV
# 4308              0    Automatic   Garfield    NJ           SUV
# 2976              2    Automatic     Newark    NJ         Sedan
# 139               0    Automatic   Brooklyn    NY  Pickup Truck
# 5516              0    Automatic  Daly City    CA         Sedan
# 1010              1    Automatic   Secaucus    NJ           SUV
# 3299              0    Automatic  Eatontown    NJ           SUV
#
#                                                engine drive_train  price
# 4882                                     3.5L V-6 Gas         AWD  36731
# 7190                                     3.5L V-6 Gas         FWD  42988
# 8980                                2.5L Inline-4 Gas         FWD  24998
# 3656                                     3.2L V-6 Gas         4WD  29997
# 4308                                3.0L Inline-6 Gas         AWD  11399
# 2976                   1.5L Inline-4 Gas Turbocharged         FWD  25995
# 139                                      5.3L V-8 Gas         4WD   4999
# 5516                                     3.6L V-6 Gas         RWD  28998
# 1010  2.0L Inline-4 Gas Supercharged and Turbocharged         AWD  47886
# 3299                                     3.6L V-6 Gas         4WD  31999

# %%
#previewing the columns
df.columns
# Out:
# Index(['index', 'brand', 'model', 'mileage', 'year', 'fuel_type', 'ownerCount',
#        'accidentCount', 'transmission', 'city', 'state', 'body_style',
#        'engine', 'drive_train', 'price'],
#       dtype='object')

# %%
#previewing the dimensions or shape (rows and columns)of the data

df.shape
# Out:
# (10128, 15)

# %% [markdown]
# #### There are 10,128 rows and 15 columns

# %%
#previewing the information about the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10128 entries, 0 to 10127
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          10128 non-null  int64
#  1   brand          10128 non-null  object
#  2   model          10128 non-null  object
#  3   mileage        10128 non-null  int64
#  4   year           10128 non-null  int64
#  5   fuel_type      10128 non-null  object
#  6   ownerCount     10128 non-null  float64
#  7   accidentCount  10128 non-null  int64
#  8   transmission   10128 non-null  object
#  9   city           10128 non-null  object
#  10  state          10128 non-null  object
#  11  body_style     10128 non-null  object
#  12  engine         10128 non-null  object
#  13  drive_train    10128 non-null  object
#  14  price          10128 non-null  int64
# dtypes: float64(1), int64(5), object(9)
# memory usage: 1.2+ MB

# %%
#previewing the summary numerical statistics of our data

df.describe()
# Out:
#               index        mileage          year    ownerCount  accidentCount  \
# count  10128.000000   10128.000000  10128.000000  10128.000000   10128.000000
# mean    5067.788606   47844.902449   2017.591035      1.484301       0.165482
# std     2927.858320   35535.861685      2.790433      0.784685       0.444917
# min        0.000000      17.000000   1998.000000      0.000000       0.000000
# 25%     2532.750000   23465.750000   2017.000000      1.000000       0.000000
# 50%     5065.500000   38739.500000   2018.000000      1.000000       0.000000
# 75%     7604.250000   61533.000000   2019.000000      2.000000       0.000000
# max    10138.000000  376352.000000   2022.000000      9.000000       5.000000
#
#                price
# count   10128.000000
# mean    31203.593503
# std     20124.758054
# min      1899.000000
# 25%     21988.000000
# 50%     27998.000000
# 75%     36722.750000
# max    442500.000000

# %%
#previewing both numerical and categorical statistics

df.describe(include="all")
# Out:
#                index  brand   model        mileage          year fuel_type  \
# count   10128.000000  10128   10128   10128.000000  10128.000000     10128
# unique           NaN     48     444            NaN           NaN         7
# top              NaN   Ford  Accord            NaN           NaN       Gas
# freq             NaN   1146     296            NaN           NaN      9590
# mean     5067.788606    NaN     NaN   47844.902449   2017.591035       NaN
# std      2927.858320    NaN     NaN   35535.861685      2.790433       NaN
# min         0.000000    NaN     NaN      17.000000   1998.000000       NaN
# 25%      2532.750000    NaN     NaN   23465.750000   2017.000000       NaN
# 50%      5065.500000    NaN     NaN   38739.500000   2018.000000       NaN
# 75%      7604.250000    NaN     NaN   61533.000000   2019.000000       NaN
# max     10138.000000    NaN     NaN  376352.000000   2022.000000       NaN
#
#           ownerCount  accidentCount transmission       city  state body_style  \
# count   10128.000000   10128.000000        10128      10128  10128      10128
# unique           NaN            NaN            2        187      5         11
# top              NaN            NaN    Automatic  Daly City     CA        SUV
# freq             NaN            NaN         9837       2804   5060       4871
# mean        1.484301       0.165482          NaN        NaN    NaN        NaN
# std         0.784685       0.444917          NaN        NaN    NaN        NaN
# min         0.000000       0.000000          NaN        NaN    NaN        NaN
# 25%         1.000000       0.000000          NaN        NaN    NaN        NaN
# 50%         1.000000       0.000000          NaN        NaN    NaN        NaN
# 75%         2.000000       0.000000          NaN        NaN    NaN        NaN
# max         9.000000       5.000000          NaN        NaN    NaN        NaN
#
#                                 engine drive_train          price
# count                            10128       10128   10128.000000
# unique                             164           4            NaN
# top     2.0L Inline-4 Gas Turbocharged         FWD            NaN
# freq                              1435        3524            NaN
# mean                               NaN         NaN   31203.593503
# std                                NaN         NaN   20124.758054
# min                                NaN         NaN    1899.000000
# 25%                                NaN         NaN   21988.000000
# 50%                                NaN         NaN   27998.000000
# 75%                                NaN         NaN   36722.750000
# max                                NaN         NaN  442500.000000

# %%
#checking for missing values in our data

df.isna().sum()
# Out:
# index            0
# brand            0
# model            0
# mileage          0
# year             0
# fuel_type        0
# ownerCount       0
# accidentCount    0
# transmission     0
# city             0
# state            0
# body_style       0
# engine           0
# drive_train      0
# price            0
# dtype: int64

# %%
#checking for duplicated values in our data

df.duplicated().sum()
# Out:
# 0

# %%
#checking unique values

df.nunique()
# Out:
# index            10128
# brand               48
# model              444
# mileage           9006
# year                25
# fuel_type            7
# ownerCount           9
# accidentCount        6
# transmission         2
# city               187
# state                5
# body_style          11
# engine             164
# drive_train          4
# price             3441
# dtype: int64

# %% [markdown]
# ## 3.Exploratory Data Analysis --Data Wrangling\Cleaning

# %%
# we need to remove the index column

df.drop('index',axis=1,inplace=True)

# %% [markdown]
# #### Encoding categorical values to numerical values

# %%
#Instantiation

le=LabelEncoder()

# %%
df['brand'] = le.fit_transform(df['brand'])
df['model'] = le.fit_transform(df['model'])
df['transmission'] = le.fit_transform(df['transmission'])
df['drive_train']  = le.fit_transform(df['drive_train'])
df['fuel_type']    = le.fit_transform(df['fuel_type'])
df['body_style'] = le.fit_transform(df['body_style'])
df['engine'] = le.fit_transform(df['engine'])
df['state'] = le.fit_transform(df['state'])

# %%
df.columns
# Out:
# Index(['brand', 'model', 'mileage', 'year', 'fuel_type', 'ownerCount',
#        'accidentCount', 'transmission', 'city', 'state', 'body_style',
#        'engine', 'drive_train', 'price'],
#       dtype='object')

# %% [markdown]
# ## 4.Data Visualization

# %% [markdown]
# ### I.Univariate analysis

# %% [markdown]
# ####     Mileage

# %%
sns.displot(y='mileage',data=df,bins=60)

# %% [markdown]
# #### Year

# %%
sns.displot(x='year',data=df,bins=30)

# %% [markdown]
# #### Fuel Type

# %%
# 0 CNG
# 1 Diesel
# 2 Electric
# 3 Gas
# 4 Hybrid
# 5 Hydrogen
# 6 Plug-In Hybrid

sns.countplot(data=df,y='fuel_type')
# Out:
# <AxesSubplot: xlabel='count', ylabel='fuel_type'>

# %% [markdown]
# #### Owner Count

# %%
sns.countplot(data=df,x='ownerCount')
# Out:
# <AxesSubplot: xlabel='ownerCount', ylabel='count'>

# %% [markdown]
# #### Accident Count

# %%
sns.countplot(data=df,x='accidentCount')
# Out:
# <AxesSubplot: xlabel='accidentCount', ylabel='count'>

# %% [markdown]
# #### Transmission

# %%
# 0 automatic
# 1 Manual

sns.countplot(data=df,x='transmission',)
# Out:
# <AxesSubplot: xlabel='transmission', ylabel='count'>

# %% [markdown]
# #### State

# %%
sns.displot(x='state',data=df)

# %% [markdown]
# #### Drive Train

# %%
# 0 4WD
# 1 AWD
# 2 FWD
# 3 RWD


sns.histplot(x='drive_train',data=df)
# Out:
# <AxesSubplot: xlabel='drive_train', ylabel='Count'>

# %% [markdown]
# #### Price

# %%
sns.displot(x='price',data=df,bins=60)

# %% [markdown]
# ### II.Bivariate analysis

# %% [markdown]
# #### mileage vs price

# %%
sns.scatterplot(data=df,x='mileage',y='price')
# Out:
# <AxesSubplot: xlabel='mileage', ylabel='price'>

# %% [markdown]
# #### year vs price

# %%
plt.figure(figsize=(20,15))
sns.barplot(data=df,x='year',y='price')
# Out:
# <AxesSubplot: xlabel='year', ylabel='price'>

# %% [markdown]
# #### fuel_type vs price with trasmission as hue

# %%
# 0 CNG
# 1 Diesel
# 2 Electric
# 3 Gas
# 4 Hybrid
# 5 Hydrogen
# 6 Plug-In Hybrid

plt.figure(figsize=(20,10))
sns.barplot(data=df,x='fuel_type',y='price',hue='transmission')
# Out:
# <AxesSubplot: xlabel='fuel_type', ylabel='price'>

# %% [markdown]
# #### owner count vs price with accident count as hue

# %%
plt.figure(figsize=(20,15))
sns.barplot(data=df,x='ownerCount',y='price',hue='accidentCount')
# Out:
# <AxesSubplot: xlabel='ownerCount', ylabel='price'>

# %% [markdown]
# ####  state vs price

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df,x='state',y='price')
# Out:
# <AxesSubplot: xlabel='state', ylabel='price'>

# %% [markdown]
# #### drive train vs price with transmission as hue

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='drive_train',y='price',data=df,hue='transmission')
# Out:
# <AxesSubplot: xlabel='drive_train', ylabel='price'>

# %% [markdown]
# ## 5.Data Preprocessing and Feature Engineering

# %% [markdown]
# ### correlation

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4880\1950816695.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# <AxesSubplot: >

# %% [markdown]
# ### Removing outliers

# %%
df.head()
# Out:
#    brand  model  mileage  year  fuel_type  ownerCount  accidentCount  \
# 0     32    167    18386  2019          3         1.0              0
# 1     32     63    41829  2018          3         1.0              0
# 2     32     63    22667  2018          3         1.0              0
# 3     12     22    15104  2005          3         2.0              0
# 4     32    165    33163  2019          3         1.0              0
#
#    transmission      city  state  body_style  engine  drive_train   price
# 0             0  New York      3           8      34            1   37906
# 1             0  New York      3           9      34            1   31901
# 2             0  New York      3           9      34            1   33906
# 3             0  New York      3           3     141            3  110500
# 4             0  New York      3           8      34            1   32904

# %%
#Removing categorical columns

df.drop(['city'],axis=1,inplace=True)

# %%
sns.boxplot(x='price',data = df)
# Out:
# <AxesSubplot: xlabel='price'>

# %%
#remove outliers in all the columns

df = df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]
df.shape
# Out:
# (8825, 13)

# %%
plt.figure(figsize=(12,8))
sns.displot(df['price'])

# %%
df.head()
# Out:
#    brand  model  mileage  year  fuel_type  ownerCount  accidentCount  \
# 0     32    167    18386  2019          3         1.0              0
# 1     32     63    41829  2018          3         1.0              0
# 2     32     63    22667  2018          3         1.0              0
# 4     32    165    33163  2019          3         1.0              0
# 5     32    168    18421  2018          3         1.0              1
#
#    transmission  state  body_style  engine  drive_train  price
# 0             0      3           8      34            1  37906
# 1             0      3           9      34            1  31901
# 2             0      3           9      34            1  33906
# 4             0      3           8      34            1  32904
# 5             0      3           8      88            1  43901

# %% [markdown]
# ### scaling the data

# %%
trans = StandardScaler()

# %% [markdown]
# #### defining predictor variables and target variable

# %%
df.columns
# Out:
# Index(['brand', 'model', 'mileage', 'year', 'fuel_type', 'ownerCount',
#        'accidentCount', 'transmission', 'state', 'body_style', 'engine',
#        'drive_train', 'price'],
#       dtype='object')

# %%
#Dependent variable is also referred as target variable and the independent variables are called the predictors.

X = df.drop(['price','brand','model'],axis=1)
y = df['price']

# %%
X.to_csv('x_cleaned')

# %%
#scaling predictor variable

X = trans.fit_transform(X.values)
X = pd.DataFrame(X)

# %% [markdown]
# #### splitting data into train and test set

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=42,shuffle=True)

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# #### instantiating our linear regression model and fitting our model to the data

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### ANN

# %%
model = Sequential()

# %%
model.add(Dense(12,activation='relu'))
model.add(Dense(24,activation='relu'))
model.add(Dense(24,activation='relu'))
model.add(Dense(12,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(X_train,y_train.values,validation_data=(X_test,y_test.values),batch_size=128, epochs= 150 )
# Out:
# Epoch 1/150
# 49/49 [==============================] - 1s 5ms/step - loss: 1075175040.0000 - val_loss: 1088262144.0000
# Epoch 2/150
# 49/49 [==============================] - 0s 3ms/step - loss: 1074518912.0000 - val_loss: 1086576000.0000
# Epoch 3/150
# 49/49 [==============================] - 0s 3ms/step - loss: 1069394880.0000 - val_loss: 1074905344.0000
# Epoch 4/150
# 49/49 [==============================] - 0s 3ms/step - loss: 1042778688.0000 - val_loss: 1024171136.0000
# Epoch 5/150
# 49/49 [==============================] - 0s 3ms/step - loss: 951306176.0000 - val_loss: 876521024.0000
# Epoch 6/150
# 49/49 [==============================] - 0s 3ms/step - loss: 736988224.0000 - val_loss: 587151552.0000
# Epoch 7/150
# 49/49 [==============================] - 0s 3ms/step - loss: 417896416.0000 - val_loss: 271588736.0000
# Epoch 8/150
# 49/49 [==============================] - 0s 3ms/step - loss: 192007008.0000 - val_loss: 153163008.0000
# Epoch 9/150
# 49/49 [==============================] - 0s 3ms/step - loss: 138197712.0000 - val_loss: 134246368.0000
# Epoch 10/150
# 49/49 [==============================] - 0s 3ms/step - loss: 124808016.0000 - val_loss: 123861728.0000
# Epoch 11/150
# 49/49 [==============================] - 0s 3ms/step - loss: 115884208.0000 - val_loss: 116427352.0000
# Epoch 12/150
# 49/49 [==============================] - 0s 3ms/step - loss: 109328648.0000 - val_loss: 110784328.0000
# Epoch 13/150
# 49/49 [==============================] - 0s 3ms/step - loss: 104225784.0000 - val_loss: 106269976.0000
# Epoch 14/150
# 49/49 [==============================] - 0s 3ms/step - loss: 100105408.0000 - val_loss: 102530128.0000
# Epoch 15/150
# 49/49 [==============================] - 0s 3ms/step - loss: 96790944.0000 - val_loss: 99578416.0000
# Epoch 16/150
# 49/49 [==============================] - 0s 3ms/step - loss: 94153968.0000 - val_loss: 97060552.0000
# Epoch 17/150
# 49/49 [==============================] - 0s 3ms/step - loss: 91838472.0000 - val_loss: 94983296.0000
# Epoch 18/150
# 49/49 [==============================] - 0s 3ms/step - loss: 89897952.0000 - val_loss: 93092768.0000
# Epoch 19/150
# 49/49 [==============================] - 0s 3ms/step - loss: 88364704.0000 - val_loss: 91504256.0000
# Epoch 20/150
# 49/49 [==============================] - 0s 3ms/step - loss: 86920528.0000 - val_loss: 90207424.0000
# Epoch 21/150
# 49/49 [==============================] - 0s 3ms/step - loss: 85704664.0000 - val_loss: 88968368.0000
# Epoch 22/150
# 49/49 [==============================] - 0s 3ms/step - loss: 84728168.0000 - val_loss: 87887160.0000
# Epoch 23/150
# 49/49 [==============================] - 0s 3ms/step - loss: 83593704.0000 - val_loss: 86926008.0000
# Epoch 24/150
# 49/49 [==============================] - 0s 3ms/step - loss: 82773960.0000 - val_loss: 86092408.0000
# Epoch 25/150
# 49/49 [==============================] - 0s 3ms/step - loss: 81913488.0000 - val_loss: 85312944.0000
# Epoch 26/150
# 49/49 [==============================] - 0s 3ms/step - loss: 81268400.0000 - val_loss: 84570656.0000
# Epoch 27/150
# 49/49 [==============================] - 0s 3ms/step - loss: 80613952.0000 - val_loss: 83979784.0000
# Epoch 28/150
# 49/49 [==============================] - 0s 3ms/step - loss: 80080904.0000 - val_loss: 83333176.0000
# Epoch 29/150
# 49/49 [==============================] - 0s 3ms/step - loss: 79539208.0000 - val_loss: 82833248.0000
# Epoch 30/150
# 49/49 [==============================] - 0s 3ms/step - loss: 79143216.0000 - val_loss: 82347648.0000
# Epoch 31/150
# 49/49 [==============================] - 0s 3ms/step - loss: 78668864.0000 - val_loss: 81964456.0000
# Epoch 32/150
# 49/49 [==============================] - 0s 3ms/step - loss: 78348192.0000 - val_loss: 81424744.0000
# Epoch 33/150
# 49/49 [==============================] - 0s 3ms/step - loss: 77850424.0000 - val_loss: 81005408.0000
# Epoch 34/150
# 49/49 [==============================] - 0s 3ms/step - loss: 77488784.0000 - val_loss: 80571936.0000
# Epoch 35/150
# 49/49 [==============================] - 0s 3ms/step - loss: 77122704.0000 - val_loss: 80250568.0000
# Epoch 36/150
# 49/49 [==============================] - 0s 3ms/step - loss: 76887576.0000 - val_loss: 79837144.0000
# Epoch 37/150
# 49/49 [==============================] - 0s 3ms/step - loss: 76558904.0000 - val_loss: 79503256.0000
# Epoch 38/150
# 49/49 [==============================] - 0s 3ms/step - loss: 76134040.0000 - val_loss: 79163168.0000
# Epoch 39/150
# 49/49 [==============================] - 0s 3ms/step - loss: 75797728.0000 - val_loss: 78964248.0000
# Epoch 40/150
# 49/49 [==============================] - 0s 3ms/step - loss: 75505824.0000 - val_loss: 78601288.0000
# Epoch 41/150
# 49/49 [==============================] - 0s 3ms/step - loss: 75321544.0000 - val_loss: 78397648.0000
# Epoch 42/150
# 49/49 [==============================] - 0s 3ms/step - loss: 75008888.0000 - val_loss: 78130720.0000
# Epoch 43/150
# 49/49 [==============================] - 0s 3ms/step - loss: 74724504.0000 - val_loss: 77827096.0000
# Epoch 44/150
# 49/49 [==============================] - 0s 3ms/step - loss: 74512408.0000 - val_loss: 77607200.0000
# Epoch 45/150
# 49/49 [==============================] - 0s 3ms/step - loss: 74248424.0000 - val_loss: 77300584.0000
# Epoch 46/150
# 49/49 [==============================] - 0s 3ms/step - loss: 74213824.0000 - val_loss: 77242496.0000
# Epoch 47/150
# 49/49 [==============================] - 0s 3ms/step - loss: 73839776.0000 - val_loss: 76964784.0000
# Epoch 48/150
# 49/49 [==============================] - 0s 3ms/step - loss: 73654504.0000 - val_loss: 76756536.0000
# Epoch 49/150
# 49/49 [==============================] - 0s 3ms/step - loss: 73494176.0000 - val_loss: 76680936.0000
# Epoch 50/150
# 49/49 [==============================] - 0s 3ms/step - loss: 73400704.0000 - val_loss: 76402408.0000
# Epoch 51/150
# 49/49 [==============================] - 0s 3ms/step - loss: 73247720.0000 - val_loss: 76258624.0000
# Epoch 52/150
# 49/49 [==============================] - 0s 3ms/step - loss: 73004008.0000 - val_loss: 76106408.0000
# Epoch 53/150
# 49/49 [==============================] - 0s 3ms/step - loss: 72888704.0000 - val_loss: 75925224.0000
# Epoch 54/150
# 49/49 [==============================] - 0s 3ms/step - loss: 72812152.0000 - val_loss: 75802904.0000
# Epoch 55/150
# 49/49 [==============================] - 0s 3ms/step - loss: 72636064.0000 - val_loss: 75656432.0000
# Epoch 56/150
# 49/49 [==============================] - 0s 3ms/step - loss: 72522552.0000 - val_loss: 75620360.0000
# Epoch 57/150
# 49/49 [==============================] - 0s 3ms/step - loss: 72431520.0000 - val_loss: 75422616.0000
# Epoch 58/150
# 49/49 [==============================] - 0s 3ms/step - loss: 72318560.0000 - val_loss: 75377848.0000
# Epoch 59/150
# 49/49 [==============================] - 0s 3ms/step - loss: 72229040.0000 - val_loss: 75239304.0000
# Epoch 60/150
# 49/49 [==============================] - 0s 3ms/step - loss: 72152312.0000 - val_loss: 75188368.0000
# Epoch 61/150
# 49/49 [==============================] - 0s 3ms/step - loss: 72061640.0000 - val_loss: 75079432.0000
# Epoch 62/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71992592.0000 - val_loss: 75219888.0000
# Epoch 63/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71944240.0000 - val_loss: 75039520.0000
# Epoch 64/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71855568.0000 - val_loss: 75028840.0000
# Epoch 65/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71923896.0000 - val_loss: 74920352.0000
# Epoch 66/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71767168.0000 - val_loss: 74914824.0000
# Epoch 67/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71724496.0000 - val_loss: 74981064.0000
# Epoch 68/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71731304.0000 - val_loss: 74783504.0000
# Epoch 69/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71710408.0000 - val_loss: 74965792.0000
# Epoch 70/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71673528.0000 - val_loss: 74680800.0000
# Epoch 71/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71574960.0000 - val_loss: 74637976.0000
# Epoch 72/150
# 49/49 [==============================] - 0s 2ms/step - loss: 71506680.0000 - val_loss: 74582336.0000
# Epoch 73/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71454328.0000 - val_loss: 74529544.0000
# Epoch 74/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71372576.0000 - val_loss: 74446632.0000
# Epoch 75/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71344760.0000 - val_loss: 74419768.0000
# Epoch 76/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71290744.0000 - val_loss: 74368056.0000
# Epoch 77/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71285144.0000 - val_loss: 74370616.0000
# Epoch 78/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71233376.0000 - val_loss: 74706336.0000
# Epoch 79/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71367184.0000 - val_loss: 74400192.0000
# Epoch 80/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71256608.0000 - val_loss: 74239344.0000
# Epoch 81/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71146016.0000 - val_loss: 74214648.0000
# Epoch 82/150
# 49/49 [==============================] - 0s 2ms/step - loss: 71176368.0000 - val_loss: 74309456.0000
# Epoch 83/150
# 49/49 [==============================] - 0s 2ms/step - loss: 71066440.0000 - val_loss: 74238488.0000
# Epoch 84/150
# 49/49 [==============================] - 0s 2ms/step - loss: 71043784.0000 - val_loss: 74207328.0000
# Epoch 85/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71133664.0000 - val_loss: 74139552.0000
# Epoch 86/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71009184.0000 - val_loss: 74124800.0000
# Epoch 87/150
# 49/49 [==============================] - 0s 3ms/step - loss: 71013976.0000 - val_loss: 74285280.0000
# Epoch 88/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70949912.0000 - val_loss: 74141576.0000
# Epoch 89/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70929536.0000 - val_loss: 74095016.0000
# Epoch 90/150
# 49/49 [==============================] - 0s 2ms/step - loss: 70884600.0000 - val_loss: 74133160.0000
# Epoch 91/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70857824.0000 - val_loss: 74090216.0000
# Epoch 92/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70875632.0000 - val_loss: 74088056.0000
# Epoch 93/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70929384.0000 - val_loss: 74029616.0000
# Epoch 94/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70893688.0000 - val_loss: 74053456.0000
# Epoch 95/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70766320.0000 - val_loss: 73949456.0000
# Epoch 96/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70764584.0000 - val_loss: 74001912.0000
# Epoch 97/150
# 49/49 [==============================] - 0s 2ms/step - loss: 70754688.0000 - val_loss: 74076592.0000
# Epoch 98/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70785152.0000 - val_loss: 74288632.0000
# Epoch 99/150
# 49/49 [==============================] - 0s 2ms/step - loss: 70715072.0000 - val_loss: 73937248.0000
# Epoch 100/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70658408.0000 - val_loss: 73902712.0000
# Epoch 101/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70710832.0000 - val_loss: 73934792.0000
# Epoch 102/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70631072.0000 - val_loss: 73887040.0000
# Epoch 103/150
# 49/49 [==============================] - 0s 2ms/step - loss: 70605016.0000 - val_loss: 73843768.0000
# Epoch 104/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70589112.0000 - val_loss: 74055352.0000
# Epoch 105/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70691832.0000 - val_loss: 74033872.0000
# Epoch 106/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70623792.0000 - val_loss: 73851360.0000
# Epoch 107/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70565176.0000 - val_loss: 73881656.0000
# Epoch 108/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70582200.0000 - val_loss: 73855344.0000
# Epoch 109/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70495352.0000 - val_loss: 73841800.0000
# Epoch 110/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70531704.0000 - val_loss: 73770912.0000
# Epoch 111/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70457944.0000 - val_loss: 73848112.0000
# Epoch 112/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70572832.0000 - val_loss: 73918456.0000
# Epoch 113/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70483848.0000 - val_loss: 73740208.0000
# Epoch 114/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70446520.0000 - val_loss: 73778504.0000
# Epoch 115/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70469064.0000 - val_loss: 73654088.0000
# Epoch 116/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70396640.0000 - val_loss: 73719752.0000
# Epoch 117/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70332512.0000 - val_loss: 73690640.0000
# Epoch 118/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70374872.0000 - val_loss: 73618448.0000
# Epoch 119/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70305448.0000 - val_loss: 73578528.0000
# Epoch 120/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70347032.0000 - val_loss: 73629968.0000
# Epoch 121/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70307792.0000 - val_loss: 73648008.0000
# Epoch 122/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70310896.0000 - val_loss: 73613752.0000
# Epoch 123/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70299048.0000 - val_loss: 73583920.0000
# Epoch 124/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70242656.0000 - val_loss: 73587752.0000
# Epoch 125/150
# 49/49 [==============================] - 0s 6ms/step - loss: 70243184.0000 - val_loss: 73554352.0000
# Epoch 126/150
# 49/49 [==============================] - 0s 6ms/step - loss: 70274696.0000 - val_loss: 73546328.0000
# Epoch 127/150
# 49/49 [==============================] - 0s 5ms/step - loss: 70191960.0000 - val_loss: 73517640.0000
# Epoch 128/150
# 49/49 [==============================] - 0s 5ms/step - loss: 70162640.0000 - val_loss: 73476872.0000
# Epoch 129/150
# 49/49 [==============================] - 0s 5ms/step - loss: 70188408.0000 - val_loss: 73500312.0000
# Epoch 130/150
# 49/49 [==============================] - 0s 5ms/step - loss: 70192056.0000 - val_loss: 73542496.0000
# Epoch 131/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70229736.0000 - val_loss: 73644192.0000
# Epoch 132/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70063784.0000 - val_loss: 73518184.0000
# Epoch 133/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70074224.0000 - val_loss: 73644672.0000
# Epoch 134/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70111656.0000 - val_loss: 73360904.0000
# Epoch 135/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70011368.0000 - val_loss: 73446648.0000
# Epoch 136/150
# 49/49 [==============================] - 0s 2ms/step - loss: 70088000.0000 - val_loss: 73339960.0000
# Epoch 137/150
# 49/49 [==============================] - 0s 2ms/step - loss: 70065400.0000 - val_loss: 73374768.0000
# Epoch 138/150
# 49/49 [==============================] - 0s 3ms/step - loss: 69964792.0000 - val_loss: 73280960.0000
# Epoch 139/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70059024.0000 - val_loss: 73335928.0000
# Epoch 140/150
# 49/49 [==============================] - 0s 3ms/step - loss: 69942904.0000 - val_loss: 73301424.0000
# Epoch 141/150
# 49/49 [==============================] - 0s 3ms/step - loss: 70009080.0000 - val_loss: 73286000.0000
# Epoch 142/150
# 49/49 [==============================] - 0s 3ms/step - loss: 69927544.0000 - val_loss: 73323200.0000
# Epoch 143/150
# 49/49 [==============================] - 0s 3ms/step - loss: 69914408.0000 - val_loss: 73264976.0000
# Epoch 144/150
# 49/49 [==============================] - 0s 2ms/step - loss: 69857952.0000 - val_loss: 73210528.0000
# Epoch 145/150
# 49/49 [==============================] - 0s 3ms/step - loss: 69851184.0000 - val_loss: 73197584.0000
# Epoch 146/150
# 49/49 [==============================] - 0s 3ms/step - loss: 69871144.0000 - val_loss: 73237016.0000
# Epoch 147/150
# 49/49 [==============================] - 0s 3ms/step - loss: 69863744.0000 - val_loss: 73141712.0000
# Epoch 148/150
# 49/49 [==============================] - 0s 3ms/step - loss: 69819688.0000 - val_loss: 73118008.0000
# Epoch 149/150
# 49/49 [==============================] - 0s 3ms/step - loss: 69758120.0000 - val_loss: 73446704.0000
# Epoch 150/150
# 49/49 [==============================] - 0s 3ms/step - loss: 69791040.0000 - val_loss: 73097520.0000

# %% [markdown]
# ## 7.Evaluation

# %% [markdown]
# ### I. Linear Regresssion Model

# %%
# print the intercept

print(lm.intercept_)
# Out:
# 30621.86098524887

# %%
#Let's grab predictions off our test set and see how well it did!

lr_predictions = lm.predict(X_test)

# %%
#plotting actual values vs predicted values

plt.scatter(y_test,lr_predictions)

#perfect prediction

plt.plot(y_test,y_test,'r')

# %% [markdown]
# ###  Regression Evaluation Metrics

# %% [markdown]
# Here are three common evaluation metrics for regression problems:
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# All of these are **loss functions**, because we want to minimize them.

# %%
#Variance

metrics.explained_variance_score(y_test,lr_predictions)
# Out:
# 0.47198151102727104

# %%
print('MAE:', metrics.mean_absolute_error(y_test, lr_predictions))
print('MSE:', metrics.mean_squared_error(y_test, lr_predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, lr_predictions)))
# Out:
# MAE: 6160.031092515207
# MSE: 76297123.0023174
# RMSE: 8734.822436793858

# %%
df['price'].mean()
# Out:
# 30620.10696883853

# %% [markdown]
# nce our mean absoulute error is **6092 it means we are off by about **20%** from the mean.

# %% [markdown]
# ### II. ANN Model

# %%
loss = pd.DataFrame(model.history.history)

# %%
loss.plot()
# Out:
# <AxesSubplot: >

# %%
ann_predictions = model.predict(X_test)
# Out:
# 83/83 [==============================] - 0s 1ms/step

# %%
print('MAE:', metrics.mean_absolute_error(y_test, ann_predictions))
print('MSE:', metrics.mean_squared_error(y_test, ann_predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, ann_predictions)))
# Out:
# MAE: 6025.666273134352
# MSE: 73097515.2193658
# RMSE: 8549.708487391006

# %%
df['price'].mean()
# Out:
# 30620.10696883853

# %% [markdown]
# Since our mean absoulute error is **5802**, it means we are off by about **19%** from the mean.

# %% [markdown]
# ANN model is better than Linear regression model since it has a lower error from the mean

# %%
#Variance

metrics.explained_variance_score(y_test,ann_predictions)
# Out:
# 0.49428567029693127

# %%
# Our predictions
plt.scatter(y_test,ann_predictions)

# Perfect predictions
plt.plot(y_test,y_test,'r')

# %% [markdown]
# ## 8.Deploying

# %%
# saving Linear regression model

filename = 'finalized_model.sav'
pickle.dump(lm,open(filename,'wb'))

# %%
# saving ANN model 

model.save("model",save_format='h5')

# %%
# loading model
saved_model = load_model("model")

# %%
sample = df.sample()
sample
# Out:
#       brand  model  mileage  year  fuel_type  ownerCount  accidentCount  \
# 6380     21     96    25645  2018          3         2.0              0
#
#       transmission  state  body_style  engine  drive_train  price
# 6380             0      0           8      49            0  24998

# %%
# trans.inverse_transform(sample)
sample = sample.drop(['brand','model','price'],axis=1)
trans.transform(sample.values)
# Out:
# array([[ 0.2186849 , -1.49642038, -5.14770119,  1.03283847, -0.36649525,
#          0.        , -0.93891563, -3.00324638,  2.63068725,  0.68287424]])

# %%
result = saved_model.predict(sample)
# Out:
# 1/1 [==============================] - 0s 76ms/step

# %%
# # Our predictions
# plt.scatter(y_test,result)

# # Perfect predictions
# plt.plot(y_test,y_test,'r')

# %%
result
# Out:
# array([[2034824.8]], dtype=float32)

# %%
result[0][0]
# Out:
# 2034824.8
