# %% [markdown]
# # 1.Imports

# %%
import requests
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # 2.Python Requests

# %%
headers = {
    'authority': 'www.truecar.com',
    'sec-ch-ua': '^\\^',
    'accept': 'application/json, text/plain, */*',
    'x-xsrf-token': 'z34jPbFMHGLk5Tucf+LXwNJr1mnkyEEzd5vy4S6O6XxdW3LJR29MiN0dU8zmGwg27sG7WAChov8nVDeqfynd/A==',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-gpc': '1',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-new-york-ny/',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'tc_v=13e81b9e-57b2-4ac1-9c8c-0b2172d5d830; u=rBEACmHMVGYI3AATOGiSAg==; user_zip_code_new-york-ny=10001; user_zip_code_daly-city-ca=94016; tcip=41.60.239.119; flag-abt-static-used-landing-page=challenger; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; _abp_auth_s=6WLuPwslpJMSouWeyylr86bk9zmDfIXKX5ciJrSPsME; referrer=ZTC0000000; flag-abt-true-car-plus-landing-page-2-0=challenger; flag-abt-insurance-marketplace-on-home-and-research-pages=control2; tealium_test_field=Test_C; g_state=^{^\\^i_p^\\^:1645388596520,^\\^i_l^\\^:2^}; capselaPreferredPostalCode=10001; XSRF-TOKEN=z34jPbFMHGLk5Tucf^%^2BLXwNJr1mnkyEEzd5vy4S6O6XxdW3LJR29MiN0dU8zmGwg27sG7WAChov8nVDeqfynd^%^2FA^%^3D^%^3D; _abp_backend_session=b3g3ajB5eEVRRmxTMkJxSTVWUXFKNzQ5eTVpV1plN21NTi9Rd3IyUkMxcVZ3ZG1OT05yT1NpMk9vSUZ1SEhzN1UyczJLcDNOK3drN0xLb0toUFA1QWhuTnpWcVoxWU81akppWVpjcVBIVXQzWWFIZ1E2aEJGV3VvQXNVaStBOXpGOVExZzdHUWJkclI5SktteG84a3lBPT0tLVpNU01aVUs1eTdxdnIzRStEMDVLeWc9PQ^%^3D^%^3D--003e6f78bdbdf6dfc0f5214e276a510558b6566a; _dd_s=rum=0&expire=1645307114080; utag_main=v_id:017f13a2ced400096c6023a97df705073001806b00918^$_sn:2^$_se:11^$_ss:0^$_st:1645308014088^$dc_visit:2^$ses_id:1645304842385^%^3Bexp-session^$_pn:1^%^3Bexp-session^$dc_event:11^%^3Bexp-session',
    'if-none-match': 'W/^\\^5de65834d5b00405380c171731929bb6^\\^',
}

params = (
    ('city', 'new-york'),
    ('collapse', 'true'),
    ('fallback', 'true'),
    ('include_incentives', 'true'),
    ('include_targeted_incentives', 'true'),
    ('new_or_used', 'u'),
    ('page', '1'),
    ('per_page', '30'),
    ('postal_code', '10001'),
    ('search_event', 'true'),
    ('sort^\\[^\\]', 'best_match'),
    ('sponsored', 'true'),
    ('state', 'ny'),
)

response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings?city=new-york&collapse=true&fallback=true&include_incentives=true&include_targeted_incentives=true&new_or_used=u&page=2&per_page=30&postal_code=10001&search_event=true&sort^\[^\]=best_match&sponsored=true&state=ny', headers=headers)

# %% [markdown]
# # 3.Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# # 4.Create Json Object

# %%
result_json = response.json()

# %% [markdown]
# # 5.Output Keys

# %%
type(result_json)
# Out:
# dict

# %%
result_json.keys()
# Out:
# dict_keys(['listings', 'page', 'per_page', 'total', 'fallback', 'fallback_step', 'refine_parameters', 'display', 'list_price', 'sponsored_listings', 'location'])

# %% [markdown]
# # 6.Find Data

# %%
result_items=result_json['listings']

# %%
result_items
# Out:
# [{'vehicle': {'body_style_slug': 'suv',
#    'body_style': 'SUV',
#    'drive_train': 'AWD',
#    'engine': '2.0L Inline-4 Gas Turbocharged',
#    'fuel_type': 'Gas',
#    'make_id': 4,
#    'make_slug': 'mercedes-benz',
#    'make': 'Mercedes-Benz',
#    'model_id': 8130,
#    'model_slug': 'glc',
#    'model': 'GLC',
#    'mpg_city': 22,
#    'mpg_combined': 24,
#    'mpg_highway': 27,
#    'style_id': 62744,
#    'style_slug': 'glc-300-4matic',
#    'style': 'GLC 300 4MATIC',
#    'transmission': 'Automatic',
#    'trim_slug': 'glc-300',
#    'trim': 'GLC 300 4MATIC',
#    'trim_id': None,
#    'year': 2019,
#    'chrome_trim_id': 402571,
#    'carfax_report_available': False,
#    'enable_discount': 'yes_all_tc',
#    'exterior_color_generic': 'Blue',
#    'exterior_color_rgb': '0C1D38',
#    'exterior_color': 'Brilliant Blue Metallic',
#    'exterior_color_id': 944217,
#    'interior_color': 'Black',
#    'interior_color_generic': 'Black',
#    'interior_color_rgb': '1B1C20',
# ...

# %%
result_items[0]['vehicle']['make']
# Out:
# 'Mercedes-Benz'

# %%
result_items[0]['vehicle']['model']
# Out:
# 'GLC'

# %%
result_items[0]['vehicle']['mileage']
# Out:
# 18386

# %%
result_items[0]['vehicle']['year']
# Out:
# 2019

# %%
result_items[0]['vehicle']['fuel_type']
# Out:
# 'Gas'

# %%
result_items[0]['vehicle']['condition_history']['ownerCount']
# Out:
# 1

# %%
result_items[0]['vehicle']['condition_history']['accidentCount']
# Out:
# 0

# %%
result_items[0]['vehicle']['transmission']
# Out:
# 'Automatic'

# %%
result_items[0]['dealership']['location']['city']
# Out:
# 'New York'

# %%
result_items[0]['dealership']['location']['state']
# Out:
# 'NY'

# %%
result_items[0]['vehicle']['body_style']
# Out:
# 'SUV'

# %%
result_items[0]['vehicle']['engine']
# Out:
# '2.0L Inline-4 Gas Turbocharged'

# %%
result_items[0]['vehicle']['drive_train']
# Out:
# 'AWD'

# %%
result_items[0]['pricing']['list_price']
# Out:
# 37906

# %% [markdown]
# # 7.Combination and For Loop

# %%
make = []
model =[]
mileage = []
year = []
fuel_type = []
ownerCount = []
accidentCount = []
transmission = []
city = []
state = []
body_style = []
engine = []
drive_train = []
price = []


for result in result_items:
    make.append(result['vehicle']['make'])
    model.append(result['vehicle']['model'])
    mileage.append(result['vehicle']['mileage'])
    year.append(result['vehicle']['year'])
    fuel_type.append(result['vehicle']['fuel_type'])
    ownerCount.append(result['vehicle']['condition_history']['ownerCount'])
    accidentCount.append(result['vehicle']['condition_history']['accidentCount'])
    transmission.append(result['vehicle']['transmission'])
    city.append(result['dealership']['location']['city'])
    state.append(result['dealership']['location']['state'])
    body_style.append(result['vehicle']['body_style'])
    engine.append(result['vehicle']['engine'])
    drive_train.append(result['vehicle']['drive_train'])
    price.append(result['pricing']['list_price'])

# %% [markdown]
# # 8. DataFrames

# %%
#SINGLE PAGE

# %%
single_ny_df=pd.DataFrame({'brand':make,'model':model,'mileage':mileage,'year':year,'fuel_type':fuel_type,'ownerCount':ownerCount,'accidentCount':accidentCount,'transmission':transmission,'city':city,'state':state,'body_style':body_style,'engine':engine,'drive_train':drive_train,'price':price})

# %%
single_ny_df
# Out:
#             brand           model  mileage  year fuel_type  ownerCount  \
# 0   Mercedes-Benz             GLC    18386  2019       Gas           1
# 1   Mercedes-Benz         C-Class    41829  2018       Gas           1
# 2   Mercedes-Benz         C-Class    22667  2018       Gas           1
# 3         Ferrari  612 Scaglietti    15104  2005       Gas           2
# 4   Mercedes-Benz             GLA    33163  2019       Gas           1
# 5   Mercedes-Benz             GLE    18421  2018       Gas           1
# 6   Mercedes-Benz         C-Class     9013  2021       Gas           1
# 7   Mercedes-Benz             GLE    42197  2019       Gas           1
# 8   Mercedes-Benz             CLA    31553  2018       Gas           2
# 9           Lexus              ES    24124  2019       Gas           1
# 10  Mercedes-Benz             GLC    38815  2019       Gas           1
# 11          Lexus              RX    17248  2019       Gas           1
# ...

# %%
#MULTIPLE PAGES

# %%
make = []
model =[]
mileage = []
year =[]
fuel_type = []
ownerCount = []
accidentCount = []
transmission = []
city = []
state = []
body_style = []
engine = []
drive_train = []
price = []


for i in range(1,170):

    headers = {
        'authority': 'www.truecar.com',
        'sec-ch-ua': '^\\^',
        'accept': 'application/json, text/plain, */*',
        'x-xsrf-token': 'z34jPbFMHGLk5Tucf+LXwNJr1mnkyEEzd5vy4S6O6XxdW3LJR29MiN0dU8zmGwg27sG7WAChov8nVDeqfynd/A==',
        'sec-ch-ua-mobile': '?0',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36',
        'sec-ch-ua-platform': '^\\^Windows^\\^',
        'sec-gpc': '1',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'sec-fetch-dest': 'empty',
        'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-new-york-ny/',
        'accept-language': 'en-US,en;q=0.9',
        'cookie': 'tc_v=13e81b9e-57b2-4ac1-9c8c-0b2172d5d830; u=rBEACmHMVGYI3AATOGiSAg==; user_zip_code_new-york-ny=10001; user_zip_code_daly-city-ca=94016; tcip=41.60.239.119; flag-abt-static-used-landing-page=challenger; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; _abp_auth_s=6WLuPwslpJMSouWeyylr86bk9zmDfIXKX5ciJrSPsME; referrer=ZTC0000000; flag-abt-true-car-plus-landing-page-2-0=challenger; flag-abt-insurance-marketplace-on-home-and-research-pages=control2; tealium_test_field=Test_C; g_state=^{^\\^i_p^\\^:1645388596520,^\\^i_l^\\^:2^}; capselaPreferredPostalCode=10001; XSRF-TOKEN=z34jPbFMHGLk5Tucf^%^2BLXwNJr1mnkyEEzd5vy4S6O6XxdW3LJR29MiN0dU8zmGwg27sG7WAChov8nVDeqfynd^%^2FA^%^3D^%^3D; _abp_backend_session=b3g3ajB5eEVRRmxTMkJxSTVWUXFKNzQ5eTVpV1plN21NTi9Rd3IyUkMxcVZ3ZG1OT05yT1NpMk9vSUZ1SEhzN1UyczJLcDNOK3drN0xLb0toUFA1QWhuTnpWcVoxWU81akppWVpjcVBIVXQzWWFIZ1E2aEJGV3VvQXNVaStBOXpGOVExZzdHUWJkclI5SktteG84a3lBPT0tLVpNU01aVUs1eTdxdnIzRStEMDVLeWc9PQ^%^3D^%^3D--003e6f78bdbdf6dfc0f5214e276a510558b6566a; _dd_s=rum=0&expire=1645307114080; utag_main=v_id:017f13a2ced400096c6023a97df705073001806b00918^$_sn:2^$_se:11^$_ss:0^$_st:1645308014088^$dc_visit:2^$ses_id:1645304842385^%^3Bexp-session^$_pn:1^%^3Bexp-session^$dc_event:11^%^3Bexp-session',
        'if-none-match': 'W/^\\^5de65834d5b00405380c171731929bb6^\\^',
    }

    params = (
        ('city', 'new-york'),
        ('collapse', 'true'),
        ('fallback', 'true'),
        ('include_incentives', 'true'),
        ('include_targeted_incentives', 'true'),
        ('new_or_used', 'u'),
        ('page', str(i)),
        ('per_page', '30'),
        ('postal_code', '10001'),
        ('search_event', 'true'),
        ('sort^\\[^\\]', 'best_match'),
        ('sponsored', 'true'),
        ('state', 'ny'),
    )

    response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)
   

    result_json = response.json()
    
    result_items = result_json['listings']
    
    for result in result_items:
        make.append(result['vehicle']['make'])
        model.append(result['vehicle']['model'])
        mileage.append(result['vehicle']['mileage'])
        year.append(result['vehicle']['year'])
        fuel_type.append(result['vehicle']['fuel_type'])
        ownerCount.append(result['vehicle']['condition_history']['ownerCount'])
        accidentCount.append(result['vehicle']['condition_history']['accidentCount'])
        transmission.append(result['vehicle']['transmission'])
        city.append(result['dealership']['location']['city'])
        state.append(result['dealership']['location']['state'])
        body_style.append(result['vehicle']['body_style'])
        engine.append(result['vehicle']['engine'])
        drive_train.append(result['vehicle']['drive_train'])
        price.append(result['pricing']['list_price'])

# %%
multiple_ny_df=pd.DataFrame({'brand':make,'model':model,'mileage':mileage,'year':year,'fuel_type':fuel_type,'ownerCount':ownerCount,'accidentCount':accidentCount,'transmission':transmission,'city':city,'state':state,'body_style':body_style,'engine':engine,'drive_train':drive_train,'price':price})

# %%
multiple_ny_df
# Out:
#               brand           model  mileage  year fuel_type  ownerCount  \
# 0     Mercedes-Benz             GLC    18386  2019       Gas           1
# 1     Mercedes-Benz         C-Class    41829  2018       Gas           1
# 2     Mercedes-Benz         C-Class    22667  2018       Gas           1
# 3           Ferrari  612 Scaglietti    15104  2005       Gas           2
# 4     Mercedes-Benz             GLA    33163  2019       Gas           1
# ...             ...             ...      ...   ...       ...         ...
# 5065       INFINITI            QX50    29341  2019       Gas           1
# 5066  Mercedes-Benz             GLC    21567  2019       Gas           1
# 5067         Toyota            RAV4    30052  2020       Gas           1
# 5068         Nissan          Murano    10386  2019       Gas           1
# 5069            BMW              X5    33173  2019       Gas           1
#
#       accidentCount transmission          city state body_style  \
# ...

# %%
multiple_ny_df.duplicated().sum()
# Out:
# 0

# %%
#Multiple page San Franscisco

# %%
make = []
model =[]
mileage = []
year =[]
fuel_type = []
ownerCount = []
accidentCount = []
transmission = []
city = []
state = []
body_style = []
engine = []
drive_train = []
price = []


for i in range(1,170):

    headers = {
        'authority': 'www.truecar.com',
        'sec-ch-ua': '^\\^',
        'accept': 'application/json, text/plain, */*',
        'x-xsrf-token': 'c+CD62HeamflOaY0IZxwpHP8n56pVs1U39uvDtQwE37hxdIfl/06jdzBzmS4Za9ST1byr00/LpiPFGpFhZcn/g==',
        'sec-ch-ua-mobile': '?0',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36',
        'sec-ch-ua-platform': '^\\^Windows^\\^',
        'sec-gpc': '1',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-mode': 'cors',
        'sec-fetch-dest': 'empty',
        'referer': 'https://www.truecar.com/used-cars-for-sale/listings/location-san-francisco-ca/',
        'accept-language': 'en-US,en;q=0.9',
        'cookie': 'tc_v=13e81b9e-57b2-4ac1-9c8c-0b2172d5d830; u=rBEACmHMVGYI3AATOGiSAg==; user_zip_code_new-york-ny=10001; user_zip_code_daly-city-ca=94016; tcip=41.60.239.119; flag-abt-static-used-landing-page=challenger; _abp_auth_p=eyJhbGciOiJIUzI1NiJ9.; _abp_auth_s=6WLuPwslpJMSouWeyylr86bk9zmDfIXKX5ciJrSPsME; referrer=ZTC0000000; flag-abt-true-car-plus-landing-page-2-0=challenger; flag-abt-insurance-marketplace-on-home-and-research-pages=control2; tealium_test_field=Test_C; g_state=^{^\\^i_p^\\^:1645388596520,^\\^i_l^\\^:2^}; user_zip_code_san-francisco-ca=94102; capselaPreferredPostalCode=94102; _abp_backend_session=Njg1clZKKzZVWTVjK0IzUlk0SlYyZGI1djFNSHRocTFGMFdEa3VCTFZybDNaZzllTUFqUm8ycXdHUVloaERZRkY1Z050VlhXVVlCNXFUTU9pV1Q4bXBGWmpyMnlYU3hSU3pVK0ZXeTlQa3V0NmVDanNUcFRrNDk4YURFMXpWb01NYzVxbXBLWGJGakdUanQ4a2hrdGhnPT0tLTBJSitQZ3NCc05GV21wY1JDZGtMUnc9PQ^%^3D^%^3D--8603880da113e86b92b8ca2cea6d64e7956dc27a; XSRF-TOKEN=c^%^2BCD62HeamflOaY0IZxwpHP8n56pVs1U39uvDtQwE37hxdIfl^%^2F06jdzBzmS4Za9ST1byr00^%^2FLpiPFGpFhZcn^%^2Fg^%^3D^%^3D; _dd_s=rum=0&expire=1645308619793; utag_main=v_id:017f13a2ced400096c6023a97df705073001806b00918^$_sn:2^$_se:18^$_ss:0^$_st:1645309519798^$dc_visit:2^$ses_id:1645304842385^%^3Bexp-session^$_pn:2^%^3Bexp-session^$dc_event:18^%^3Bexp-session',
    }

    params = (
        ('city', 'san-francisco'),
        ('collapse', 'true'),
        ('fallback', 'true'),
        ('include_incentives', 'true'),
        ('include_targeted_incentives', 'true'),
        ('new_or_used', 'u'),
        ('page', str(i)),
        ('per_page', '30'),
        ('postal_code', '94102'),
        ('search_event', 'true'),
        ('sort^\\[^\\]', 'best_match'),
        ('sponsored', 'true'),
        ('state', 'ca'),
    )

    response = requests.get('https://www.truecar.com/abp/api/vehicles/used/listings', headers=headers, params=params)


    result_json = response.json()
    
    result_items = result_json['listings']
    
    for result in result_items:
        make.append(result['vehicle']['make'])
        model.append(result['vehicle']['model'])
        mileage.append(result['vehicle']['mileage'])
        year.append(result['vehicle']['year'])
        fuel_type.append(result['vehicle']['fuel_type'])
        ownerCount.append(result['vehicle']['condition_history']['ownerCount'])
        accidentCount.append(result['vehicle']['condition_history']['accidentCount'])
        transmission.append(result['vehicle']['transmission'])
        city.append(result['dealership']['location']['city'])
        state.append(result['dealership']['location']['state'])
        body_style.append(result['vehicle']['body_style'])
        engine.append(result['vehicle']['engine'])
        drive_train.append(result['vehicle']['drive_train'])
        price.append(result['pricing']['list_price'])

# %%
multiple_sf_df=pd.DataFrame({'brand':make,'model':model,'mileage':mileage,'year':year,'fuel_type':fuel_type,'ownerCount':ownerCount,'accidentCount':accidentCount,'transmission':transmission,'city':city,'state':state,'body_style':body_style,'engine':engine,'drive_train':drive_train,'price':price})

# %%
multiple_sf_df
# Out:
#               brand           model  mileage  year fuel_type  ownerCount  \
# 0            Toyota           Camry    89022  2019       Gas         2.0
# 1            Toyota         Corolla    44790  2020       Gas         1.0
# 2               BMW        3 Series    27105  2018       Gas         2.0
# 3     Mercedes-Benz         C-Class    18875  2019       Gas         1.0
# 4               BMW              X3    19127  2019       Gas         1.0
# ...             ...             ...      ...   ...       ...         ...
# 5065       Chrysler             200    65159  2015       Gas         2.0
# 5066      Chevrolet  Silverado 1500    17331  2021       Gas         1.0
# 5067           Ford          Fusion    16975  2019    Hybrid         2.0
# 5068            Ram            1500    20091  2019       Gas         2.0
# 5069         Nissan           Rogue    46116  2020       Gas         2.0
#
#       accidentCount transmission           city state    body_style  \
# ...

# %%
multiple_sf_df.duplicated().sum()
# Out:
# 1

# %%
multiple_sf_df.drop_duplicates(inplace=True)

# %%
multiple_sf_df.duplicated().sum()
# Out:
# 0

# %%
# merging both DataFrames

# %%
merged_df=pd.concat([multiple_ny_df,multiple_sf_df], ignore_index=True)

# %%
merged_df
# Out:
#                brand           model  mileage  year fuel_type  ownerCount  \
# 0      Mercedes-Benz             GLC    18386  2019       Gas         1.0
# 1      Mercedes-Benz         C-Class    41829  2018       Gas         1.0
# 2      Mercedes-Benz         C-Class    22667  2018       Gas         1.0
# 3            Ferrari  612 Scaglietti    15104  2005       Gas         2.0
# 4      Mercedes-Benz             GLA    33163  2019       Gas         1.0
# ...              ...             ...      ...   ...       ...         ...
# 10134       Chrysler             200    65159  2015       Gas         2.0
# 10135      Chevrolet  Silverado 1500    17331  2021       Gas         1.0
# 10136           Ford          Fusion    16975  2019    Hybrid         2.0
# 10137            Ram            1500    20091  2019       Gas         2.0
# 10138         Nissan           Rogue    46116  2020       Gas         2.0
#
#        accidentCount transmission           city state    body_style  \
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10139 entries, 0 to 10138
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brand          10139 non-null  object
#  1   model          10139 non-null  object
#  2   mileage        10139 non-null  int64
#  3   year           10139 non-null  int64
#  4   fuel_type      10132 non-null  object
#  5   ownerCount     10138 non-null  float64
#  6   accidentCount  10139 non-null  int64
#  7   transmission   10132 non-null  object
#  8   city           10139 non-null  object
#  9   state          10139 non-null  object
#  10  body_style     10139 non-null  object
#  11  engine         10139 non-null  object
#  12  drive_train    10139 non-null  object
#  13  price          10136 non-null  float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 1.1+ MB

# %%
merged_df.dropna(axis=0,inplace=True)

# %%
merged_df['price'] = merged_df['price'].astype('Int64')

# %%
merged_df.duplicated().sum()
# Out:
# 0

# %%
#Connect and push data to PostgreSql Database

# %%
engine = create_engine('postgresql://postgres:0112358@localhost:5432')
merged_df.to_sql('used_car_data',engine)
